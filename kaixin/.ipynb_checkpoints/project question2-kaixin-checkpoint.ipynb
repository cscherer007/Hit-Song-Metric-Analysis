# %% [markdown]
# ## Part 2: Analyze the most popular songs and artists throughout the year of 2017-2021 ( date, popularity, streams, genres, artist, track name---top 200 songs(streams) in the US, past 5 years) - Kaixin

# %%
# %matplotlib notebook
# %matplotlib inline

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Read the data and the study results
Top200songs_df_path = "Resources/Top200songs.csv"
Top200songs_df = pd.read_csv(Top200songs_df_path, encoding = "utf-8")
Top200songs_df.head(20)

# Converting dtypes using astype
Top200songs_df["Streams"]= Top200songs_df["Streams"].astype(int)
Top200songs_df["Track Name"]= Top200songs_df["Track Name"].astype(str)

# Create a new dataframe that only contains data of U.S.
Top200songs_US = Top200songs_df[Top200songs_df['name'] == "United States"]
Top200songs_US = Top200songs_US.reset_index(drop=True)
Top200songs_US.head(20)
# Out:
#     Position                                         Track Name  \
# 0          1                Bad and Boujee (feat. Lil Uzi Vert)
# 1          2                                          Fake Love
# 2          3                                            Starboy
# 3          4                                             Closer
# 4          5  I Don’t Wanna Live Forever (Fifty Shades Darke...
# 5          6                                      Black Beatles
# 6          7                   Bad Things (with Camila Cabello)
# 7          8                                           Caroline
# 8          9                                        Bounce Back
# 9         10                                   I Feel It Coming
# 10        11                        Broccoli (feat. Lil Yachty)
# 11        12                                   Don't Wanna Know
# 12        13                                            Deja Vu
# 13        14                                    Let Me Love You
# 14        15                                   X (feat. Future)
# 15        16                                          24K Magic
# 16        17                               Say You Won't Let Go
# 17        18                                           Starving
# 18        19                                In the Name of Love
# 19        20                                          One Dance
#
#                Artist  Streams  \
# 0               Migos  1293486
# 1               Drake  1179471
# 2          The Weeknd  1086272
# 3    The Chainsmokers   856349
# 4                ZAYN   803439
# 5        Rae Sremmurd   770885
# 6   Machine Gun Kelly   726097
# 7               Aminé   709420
# 8            Big Sean   704667
# 9          The Weeknd   669820
# 10   Shelley FKA DRAM   592083
# 11           Maroon 5   564578
# 12            J. Cole   552100
# 13           DJ Snake   547136
# 14          21 Savage   531623
# 15         Bruno Mars   529367
# 16       James Arthur   527210
# 17   Hailee Steinfeld   509437
# 18      Martin Garrix   506815
# 19              Drake   498653
#
#                                                   URL        Date code  \
# 0   https://open.spotify.com/track/4Km5HrUvYTaSUfi...  2017-01-04   us
# 1   https://open.spotify.com/track/343YBumqHu19cGo...  2017-01-04   us
# 2   https://open.spotify.com/track/5aAx2yezTd8zXrk...  2017-01-04   us
# 3   https://open.spotify.com/track/7BKLCZ1jbUBVqRi...  2017-01-04   us
# 4   https://open.spotify.com/track/3NdDpSvN911VPGi...  2017-01-04   us
# 5   https://open.spotify.com/track/6fujklziTHa8uoM...  2017-01-04   us
# 6   https://open.spotify.com/track/1PSBzsahR2AKwLJ...  2017-01-04   us
# 7   https://open.spotify.com/track/5hTpBe8h35rJ67e...  2017-01-04   us
# 8   https://open.spotify.com/track/0SGkqnVQo9KPytS...  2017-01-04   us
# 9   https://open.spotify.com/track/5GXAXm5YOmYT0kL...  2017-01-04   us
# 10  https://open.spotify.com/track/7yyRTcZmCiyzzJl...  2017-01-04   us
# 11  https://open.spotify.com/track/5MFzQMkrl1FOOng...  2017-01-04   us
# 12  https://open.spotify.com/track/6I6NX6tjGsxFAsI...  2017-01-04   us
# 13  https://open.spotify.com/track/4pdPtRcBmOSQDlJ...  2017-01-04   us
# 14  https://open.spotify.com/track/6fwdbPMwP1zVStm...  2017-01-04   us
# 15  https://open.spotify.com/track/6b8Be6ljOzmkOmF...  2017-01-04   us
# 16  https://open.spotify.com/track/5uCax9HTNlzGybI...  2017-01-04   us
# 17  https://open.spotify.com/track/1qOLh0tI7trd1zd...  2017-01-04   us
# 18  https://open.spotify.com/track/04DwTuZ2VBdJCCC...  2017-01-04   us
# 19  https://open.spotify.com/track/1xznGGDReH1oQq0...  2017-01-04   us
#
#              name
# 0   United States
# 1   United States
# 2   United States
# 3   United States
# 4   United States
# 5   United States
# 6   United States
# 7   United States
# 8   United States
# 9   United States
# 10  United States
# 11  United States
# 12  United States
# 13  United States
# 14  United States
# 15  United States
# 16  United States
# 17  United States
# 18  United States
# 19  United States

# %%
# Out:
# Position       int64
# Track Name    object
# Artist        object
# Streams        int64
# URL           object
# Date          object
# code          object
# name          object
# dtype: object
# /Users/yangkaixin/opt/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yangkaixin/opt/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Remove the missing data and redundant index column(Delete the first and second column)
Top200songs_US = Top200songs_US.drop(labels = "Position", axis = 1)

#Sort the table by most popular songs and export the resulting table to a new csv
Top200songs_US = Top200songs_US.sort_values(["Streams"], ascending = False)
Top200songs_US.to_csv("Resources/Top200songs_US.csv", index = False)

# %%
#Types of data
Top200songs_US.dtypes
# Out:
# Track Name    object
# Artist        object
# Streams        int64
# URL           object
# Date          object
# code          object
# name          object
# dtype: object

# %% [markdown]
# ## Part2-1
#
# We want to see the most popular songs throughout the year of 2017-2021

# %%
#Get rid of unuseful data.
Top200songs_US_df = Top200songs_US.drop(['URL','Date','code','name'],axis = 1)
Top200songs_US_df.head(20)

#Removed duplicate rows because there are many dupliceted track name.
Top200songs_US_groups = Top200songs_US_df.drop_duplicates(subset=['Track Name', 'Artist'], keep='first')

#The most-streamed songs (Top 10) from 01/2017-04/2021
Top200songs_US_groups2 = Top200songs_US_groups.drop(['Artist'],axis = 1)
Top10songs_US = Top200songs_US_groups2.iloc[0:10]
Top10songs_US = Top10songs_US.reset_index(drop=True)
Top10songs_US
# Out:
#                          Track Name  Streams
# 0                           Nonstop  5749019
# 1                   drivers license  5723851
# 2                          Survival  5219711
# 3                       Emotionless  4842941
# 4                        God's Plan  4739798
# 5                           Elevate  4686139
# 6  Mona Lisa (feat. Kendrick Lamar)  4444027
# 7                              SAD!  4437612
# 8                        STARGAZING  4244308
# 9                               KOD  4233070

# %%
#Set the x_axis ,y_axis and tick locations
x_axis = Top10songs_US['Track Name']
y_axis = Top10songs_US['Streams']
tick_locations = [value for value in x_axis]

#Chart our data, give it a title, and label the axes
plt.bar(x_axis ,y_axis, facecolor = 'r', alpha = 0.5, align = "center", width = 0.5) 

#Give it a title, and label the axes
plt.title( "Top 10 songs (2017 - 2021)")
plt.ylabel("Streams")
plt.xlabel("Track Name")

plt.ylim(0, 6000000)
plt.xticks(tick_locations, Top10songs_US['Track Name'], rotation = 'vertical')
plt.tight_layout()

# Now we have bar chart of the most-streamed songs (Top 10) from 01/2017-04/2021
plt.savefig("Images/most-streamed songs.png")
plt.show()
# Out:
# <div id='607b7270-dd88-4210-a4d0-dfe657467416'></div>

# %% [markdown]
# ## Part2-2
#
# We want to see the most popular songs and artists throughout the year of 2017-2021

# %%
#The most popular artists (Top 10) from 01/2017-04/2021
Top200artists_groups = Top200songs_US_groups.drop(['Track Name','Streams'],axis = 1)
Top200artists_groups = Top200artists_groups.reset_index(drop=True)
Top200artists_counts = pd.value_counts(Top200artists_groups["Artist"])
Top10artists = Top200artists_counts.iloc[0:10]
Top10artists
# Out:
# Taylor Swift     103
# Future            92
# Drake             88
# Trippie Redd      74
# Eminem            67
# Juice WRLD        66
# Lil Uzi Vert      64
# Logic             63
# XXXTENTACION      61
# Ariana Grande     57
# Name: Artist, dtype: int64

# %%
#Chart our data, give it a title, and label the axes
Top10artists.plot(kind = "bar", facecolor = 'green', alpha = 0.5, align = "center", width = 0.5) 

#Give it a title, and label the axes
plt.title( "Top 10 artists (2017 - 2021)")
plt.ylabel("Appreared on Spotify US")
plt.xlabel("Artists")
plt.tight_layout()

# Now we have bar chart of the most-streamed songs (Top 10) from 01/2017-04/2021
plt.savefig("Images/most popular artists.png")
plt.show()
# Out:
# <div id='7d275384-e879-4e94-a4af-0ceb083d87c5'></div>

# %% [markdown]
# ### Part2-3
#
# Trend in listening(streams) over time(date) to do a line chart
